# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name": ["Akshat", "Aanis", "Bandhan"],
    "marks": [85, 80, 90],
    "city": ["Bhopal", "Gawliar", "West Bengal"]
}

# %%
df = pd.DataFrame(dict1)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       name  marks         city
# 0   Akshat     85       Bhopal
# 1    Aanis     80      Gawliar
# 2  Bandhan     90  West Bengal

# %%
df.to_csv("marks.csv", index=False)

# %%
df.head(2)
# Out:
#      name  marks     city
# 0  Akshat     85   Bhopal
# 1   Aanis     80  Gawliar

# %%
df.tail(2)
# Out:
#       name  marks         city
# 1    Aanis     80      Gawliar
# 2  Bandhan     90  West Bengal

# %%
df.describe()
# Out:
#        marks
# count    3.0
# mean    85.0
# std      5.0
# min     80.0
# 25%     82.5
# 50%     85.0
# 75%     87.5
# max     90.0

# %%
dict2 = {
    "id": [1, 2, 3, 4],
    "salary": [85, 80, 90, 80],
}
df2 = pd.DataFrame(dict2)
df2.head()
# Out:
#    id  salary
# 0   1      85
# 1   2      80
# 2   3      90
# 3   4      80

# %%
salary_series = df2['salary']
type(salary_series)
# Out:
# pandas.core.series.Series

# %%
new_salary = salary_series.unique()
type(new_salary)
# Out:
# numpy.ndarray

# %%
new_salary.sort()

# %%
n = len(new_salary)

# %%
if n >=2:
    print(new_salary[2-1])
else:
    print("null")
# Out:
# 85
