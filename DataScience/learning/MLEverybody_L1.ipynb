# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cols = ['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist','class']
''' data_df = pd.read_csv("magic04.data", names=cols)
data_df.to_csv("MAGIC.csv", index=False) '''
# Out:
# ' data_df = pd.read_csv("magic04.data", names=cols)\ndata_df.to_csv("MAGIC.csv", index=False) '

# %%
df = pd.read_csv('MAGIC.csv')
df.head(6)
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
# 5   51.6240   21.1502  2.9085  0.2420  0.1340   50.8761  43.1887    9.8145
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g
# 5   3.6130  238.0980     g

# %%
df['class'] = (df['class'] == 'g').astype(int)

# %%
df.head(2)
# Out:
#    fLength   fWidth   fSize   fConc  fConc1    fAsym  fM3Long  fM3Trans  \
# 0  28.7967  16.0021  2.6449  0.3918  0.1982  27.7004  22.0110   -8.2027
# 1  31.6036  11.7235  2.5185  0.5303  0.3773  26.2722  23.8238   -9.9574
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1

# %%
for label in cols[:-1]:
    plt.hist(df[df['class'] == 1][label], color='blue', label='gama', alpha=0.7, density=True)
    plt.hist(df[df['class'] == 0][label], color='red', label='hadron', alpha=0.7, density=True)
    plt.title(label)
    plt.ylabel('Probability')
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %% [markdown]
# # Train => Validation => Test DataSets

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.7*len(df)), int(0.9*len(df))])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train, valid, test = np.transpose(df.sample(frac=1), [int(0.7*len(df)), int(0.9*len(df))])
#
# File C:\Python313\Lib\site-packages\numpy\_core\fromnumeric.py:702, in transpose(a, axes)
#     629 @array_function_dispatch(_transpose_dispatcher)
#     630 def transpose(a, axes=None):
#     631     """
#     632     Returns an array with axes transposed.
#     633
#    (...)    700
#     701     """
# --> 702     return _wrapfunc(a, 'transpose', axes)
#
# File C:\Python313\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# File C:\Python313\Lib\site-packages\pandas\core\frame.py:3887, in DataFrame.transpose(self, copy, *args)
#    3778 def transpose(self, *args, copy: bool = False) -> DataFrame:
#    3779     """
#    3780     Transpose index and columns.
#    3781
#    (...)   3885     dtype: object
#    3886     """
# -> 3887     nv.validate_transpose(args, {})
#    3888     # construct the args
#    3890     dtypes = list(self.dtypes)
#
# File C:\Python313\Lib\site-packages\pandas\compat\numpy\function.py:88, in CompatValidator.__call__(self, args, kwargs, fname, max_fname_arg_count, method)
#      86     validate_kwargs(fname, kwargs, self.defaults)
#      87 elif method == "both":
# ---> 88     validate_args_and_kwargs(
#      89         fname, args, kwargs, max_fname_arg_count, self.defaults
#      90     )
#      91 else:
#      92     raise ValueError(f"invalid validation method '{method}'")
#
# File C:\Python313\Lib\site-packages\pandas\util\_validators.py:223, in validate_args_and_kwargs(fname, args, kwargs, max_fname_arg_count, compat_args)
#     218         raise TypeError(
#     219             f"{fname}() got multiple values for keyword argument '{key}'"
#     220         )
#     222 kwargs.update(args_dict)
# --> 223 validate_kwargs(fname, kwargs, compat_args)
#
# File C:\Python313\Lib\site-packages\pandas\util\_validators.py:165, in validate_kwargs(fname, kwargs, compat_args)
#     163 kwds = kwargs.copy()
#     164 _check_for_invalid_keys(fname, kwargs, compat_args)
# --> 165 _check_for_default_values(fname, kwds, compat_args)
#
# File C:\Python313\Lib\site-packages\pandas\util\_validators.py:81, in _check_for_default_values(fname, arg_val_dict, compat_args)
#      78     match = arg_val_dict[key] is compat_args[key]
#      80 if not match:
# ---> 81     raise ValueError(
#      82         f"the '{key}' parameter is not supported in "
#      83         f"the pandas implementation of {fname}()"
#      84     )
#
# ValueError: the 'axes' parameter is not supported in the pandas implementation of transpose()

# %%
print(len(train[train['class'] == 1])) # gammas
print(len(train[train['class'] == 0])) # hadron
# Out:
# 8623
# 4691
